# %% [markdown]
# <a href="https://colab.research.google.com/github/Mouthika07/MED23CL202/blob/main/Dictionary_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dictionary Operations in Python**
#
# C - Create
#
# R - Read
#
# U - Update
#
# D - Delete

# %% [markdown]
# ## **Create(Add new key-value pair)**

# %%
student={}
student["name"]="Alice"
student["age"]=20
student["grade"]="A"
print(student)
# Out:
# {'name': 'Alice', 'age': 20, 'grade': 'A'}

# %% [markdown]
# ## **Read**

# %%
print(student["name"])
print(student.get("age"))
print(student.get("grade"))
print(student.get("grade","Not Available"))
# Out:
# Alice
# 20
# A
# A

# %% [markdown]
# ## **Update**

# %%
student={}
student["name"]="Bob"
student["age"]=19
student["grade"]="O"
print(student)
# Out:
# {'name': 'Bob', 'age': 19, 'grade': 'O'}

# %% [markdown]
# ## **Delete**

# %%
del student["grade"] #Completely removes key and value
print(student)
# Out:
# {'name': 'Bob', 'age': 19}

# %%
removed=student.pop("age")
#pop will remove the key but the value will be present
#still cannot access the value
print(student)
print(removed)
# Out:
# {'name': 'Bob'}
# 19

# %% [markdown]
# ## **Nested Dictionary**

# %%
#Create a nested dictionary with student data
student={
    "Alice":{"Math":80,"Science":90,"English":95},
    "Bob":{"Math":75,"Science":100,"English":80},
    "Charlie":{"Math":65,"Science":78,"English":100},
    "David":{"Math":55,"Science":90,"English":50},
    "Eva":{"Math":72,"Science":78,"English":66}
}
print(student)
# Out:
# {'Alice': {'Math': 80, 'Science': 90, 'English': 95}, 'Bob': {'Math': 75, 'Science': 100, 'English': 80}, 'Charlie': {'Math': 65, 'Science': 78, 'English': 100}, 'David': {'Math': 55, 'Science': 90, 'English': 50}, 'Eva': {'Math': 72, 'Science': 78, 'English': 66}}

# %%
import pandas as pd
data=pd.DataFrame(student)
data
# Out:
#          Alice  Bob  Charlie  David  Eva
# Math        80   75       65     55   72
# Science     90  100       78     90   78
# English     95   80      100     50   66

# %%
data=pd.DataFrame(student).T
data
# Out:
#          Math  Science  English
# Alice      80       90       95
# Bob        75      100       80
# Charlie    65       78      100
# David      55       90       50
# Eva        72       78       66

# %%
data["Average"]=data.mean(axis=1)
#axis=1 denoted row wise access to the dataframe
data
# Out:
#          Math  Science  English    Average
# Alice      80       90       95  88.333333
# Bob        75      100       80  85.000000
# Charlie    65       78      100  81.000000
# David      55       90       50  65.000000
# Eva        72       78       66  72.000000

# %%
data["Math"]=data.mean(axis=0)
#axis=0 denotes column wise access to the dataframe

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
data["Average"].plot(kind="bar",color="skyblue",edgecolor="black")
plt.title("Average mark of Students")
plt.xlabel("Student")
plt.ylabel("Average Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
data["Average"].plot(kind="line",color="skyblue", marker='o') # Added marker for better visibility
plt.title("Average mark of Students")
plt.xlabel("Student")
plt.ylabel("Average Marks")
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels
plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()

# %%
# Regenerate the data DataFrame from the original student dictionary
data = pd.DataFrame(student).T

# Add the 'Average' column back
data["Average"] = data.mean(axis=1)

display(data)
# Out:
#          Math  Science  English    Average
# Alice      80       90       95  88.333333
# Bob        75      100       80  85.000000
# Charlie    65       78      100  81.000000
# David      55       90       50  65.000000
# Eva        72       78       66  72.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
data[["Math","Science","English"]].plot(kind="bar",color=["skyblue","lightgreen","pink"])
plt.title("Average mark of Students")
plt.xlabel("Student")
plt.ylabel("Average Marks")
plt.show()
